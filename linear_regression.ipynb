# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cdtx_train = pd.read_csv('/home/bill/moneylaundring/contest/processed_dataset/cdtx_train.csv')
dp_train = pd.read_csv('/home/bill/moneylaundring/contest/processed_dataset/dp_train.csv')
remit_train = pd.read_csv('/home/bill/moneylaundring/contest/processed_dataset/remit_train.csv')

# %%
cdtx_test = pd.read_csv('/home/bill/moneylaundring/contest/processed_dataset/cdtx_test.csv')
dp_test = pd.read_csv('/home/bill/moneylaundring/contest/processed_dataset/dp_test.csv')
remit_test = pd.read_csv('/home/bill/moneylaundring/contest/processed_dataset/remit_test.csv')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
cdtx_X = cdtx_train.iloc[:,1:-1].values
cdtx_y = cdtx_train.iloc[:,-1].values

# %%
dp_train
# Out:
#         alert_key  risk_rank  occupation_code  total_asset  AGE  debit_credit  \
# 0          172802          1             19.0    1449978.0    7             1
# 1          172802          1             19.0    1449978.0    7             1
# 2          172802          1             19.0    1449978.0    7             0
# 3          172802          1             19.0    1449978.0    7             0
# 4          172802          1             19.0    1449978.0    7             1
# ...           ...        ...              ...          ...  ...           ...
# 164025     352111          1             17.0     829412.0    6             0
# 164026     352111          1             17.0     829412.0    6             0
# 164027     352111          1             17.0     829412.0    6             0
# 164028     352111          1             17.0     829412.0    6             0
# 164029     352111          1             17.0     829412.0    6             0
#
#         tx_time  tx_type   tx_amt  exchg_rate  info_asset_code  fiscTxId  \
# 0            16        2   1038.0       3.311               20      -1.0
# 1            15        2  20902.0      33.940               20      -1.0
# 2            15        2  30119.0      33.680               20      -1.0
# 3            19        2  26701.0      28.405               20      -1.0
# 4            16        2    415.0      28.435               20      -1.0
# ...         ...      ...      ...         ...              ...       ...
# 164025        1        2   3234.0       1.000               16      -1.0
# 164026       12        2   2987.0       1.000               12      -1.0
# 164027        1        2    719.0       1.000               16      -1.0
# 164028       12        2    570.0       1.000               12      -1.0
# 164029       12        2    708.0       1.000               12      -1.0
#
#         txbranch  cross_bank  ATM     cycam  date  sar_flag
# 0           -1.0           0    1       0.0     6         0
# 1           -1.0           0    1       0.0     6         0
# 2           -1.0           0    1       0.0     6         0
# 3           -1.0           0    1       0.0     6         0
# 4           -1.0           0    1       0.0     6         0
# ...          ...         ...  ...       ...   ...       ...
# 164025      -1.0           0    0  523405.0   364         0
# 164026      -1.0           0    0  523405.0   364         0
# 164027      -1.0           0    0  523405.0   364         0
# 164028      -1.0           0    0  523405.0   364         0
# 164029      -1.0           0    0  523405.0   364         0
#
# [164030 rows x 18 columns]

# %%
cdtx_test
# Out:
#       alert_key  risk_rank  occupation_code  total_asset  AGE  country  \
# 0        352291          1             17.0     182242.0    5      130
# 1        352291          1             17.0     182242.0    5      130
# 2        352298          3             12.0       2422.0    4      130
# 3        352298          3             12.0       2422.0    4      130
# 4        353041          3             12.0       2422.0    4      130
# ...         ...        ...              ...          ...  ...      ...
# 2123     364964          1             17.0     538995.0    4      130
# 2124     364977          3             12.0    1104366.0    4      130
# 2125     364977          3             12.0    1104366.0    4      130
# 2126     364983          1             13.0    1533587.0    2       42
# 2127     364983          1             13.0    1533587.0    2       65
#
#       cur_type       amt      cycam  date
# 0           47    5166.0  1033231.0   365
# 1           47    1426.0  1033231.0   365
# 2           47     200.0   150206.0   365
# 3           47     127.0   150206.0   365
# 4           47     200.0   150206.0   371
# ...        ...       ...        ...   ...
# 2123        47     530.0   305760.0   393
# 2124        47     320.0   416940.0   393
# 2125        47      41.0   416940.0   393
# 2126        53    2312.0  1706212.0   393
# 2127        53  546522.0  1706212.0   393
#
# [2128 rows x 10 columns]

# %%
dp_X = dp_train.iloc[:,1:-1].values
dp_y = dp_train.iloc[:,-1].values

# %%
remit_X = remit_train.iloc[:,1:-1].values
remit_y = remit_train.iloc[:,-1].values

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
cdtx_train
# Out:
#        alert_key  risk_rank  occupation_code  total_asset  AGE  country  \
# 0         316973          1              2.0      43580.0    2      130
# 1         345532          1              2.0     104804.0    2      130
# 2         325899          3             15.0      86994.0    5      130
# 3         344036          3             15.0      44832.0    5      130
# 4         344036          3             15.0      44832.0    5      130
# ...          ...        ...              ...          ...  ...      ...
# 48102     351269          1             17.0      33366.0    4      130
# 48103     351269          1             17.0      33366.0    4       44
# 48104     351654          2              9.0      98128.0    5      130
# 48105     351904          1             12.0       1454.0    5      130
# 48106     352111          1             17.0     829412.0    6      130
#
#        cur_type     amt      cycam  date  sar_flag
# 0            47  2671.0   174655.0   298         0
# 1            47  9256.0   174655.0   351         0
# 2            47   516.0   206512.0   320         0
# 3            47    45.0   206512.0   350         0
# 4            47   107.0   206512.0   350         0
# ...         ...     ...        ...   ...       ...
# 48102        47  1467.0   568349.0   363         0
# 48103        47  1216.0   568349.0   363         0
# 48104        47   193.0  1013581.0   364         0
# 48105        47   143.0   519218.0   364         0
# 48106        47    10.0   523405.0   364         0
#
# [48107 rows x 11 columns]

# %%
# cdtx_X_numeric = ['total_asset','amt','cycam']
# numeric_transformer = Pipeline(steps=[('scaler',StandardScaler())])
# cdtx_X_categorical = ['risk_rank','occupation_code','AGE','country','cur_type','date']
# categorical_transformer = Pipeline(steps=[('onehot',OneHotEncoder())])

# %%
# cdtx_preprocessor = ColumnTransformer(
#     transformers=[]
# )

# %%
cdtx_ct = ColumnTransformer(transformers=[('onehot', OneHotEncoder(handle_unknown='ignore'),[0,1,3,4,5,8]),('standardscaler',StandardScaler(),[2,6,7])], remainder='passthrough')
cdtx_X = cdtx_ct.fit_transform(cdtx_X)
cdtx_X
# Out:
# <48107x366 sparse matrix of type '<class 'numpy.float64'>'
# 	with 432963 stored elements in Compressed Sparse Row format>

# %%
dp_ct = ColumnTransformer(transformers=[('onehot', OneHotEncoder(handle_unknown='ignore'),[0,1,3,4,5,6,8,9,10,11,12,13,15]),('standardscaler',StandardScaler(),[2,7,14])], remainder='passthrough')
dp_X = dp_ct.fit_transform(dp_X)
dp_X
# Out:
# <164030x1874 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2624480 stored elements in Compressed Sparse Row format>

# %%
remit_ct = ColumnTransformer(transformers=[('onehot', OneHotEncoder(handle_unknown='ignore'),[0,1,3,4,7]),('standardscaler',StandardScaler(),[2,5,6])], remainder='passthrough')
remit_X = remit_ct.fit_transform(remit_X)
remit_X
# Out:
# <5438x280 sparse matrix of type '<class 'numpy.float64'>'
# 	with 43504 stored elements in Compressed Sparse Row format>

# %%
remit_train
# Out:
#       alert_key  risk_rank  occupation_code  total_asset  AGE  trans_no  \
# 0        303465          1              2.0      43580.0    2         0
# 1        304174          1              2.0      43580.0    2         0
# 2        306002          1              2.0      43580.0    2         0
# 3        306617          1              2.0      43580.0    2         0
# 4        307305          1              2.0      43580.0    2         0
# ...         ...        ...              ...          ...  ...       ...
# 3972     346383          2             15.0     379657.0    6         4
# 3973     347497          1             17.0    2044693.0    4         3
# 3974     347497          1             17.0    2044693.0    4         3
# 3975     349092          3              9.0    2708369.0    4         4
# 3976     351654          2              9.0      98128.0    5         0
#
#       trade_amount_usd      cycam  date  sar_flag
# 0              34612.0   174655.0   279         0
# 1              34736.0   174655.0   280         0
# 2              35043.0   174655.0   281         0
# 3              35409.0   174655.0   284         0
# 4              35730.0   174655.0   285         0
# ...                ...        ...   ...       ...
# 3972           10209.0   200183.0   354         0
# 3973           26609.0  1018778.0   356         0
# 3974           33752.0  1018778.0   356         0
# 3975           61348.0   304175.0   358         0
# 3976            2378.0  1013581.0   364         0
#
# [3977 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
regressor_cdtx = LinearRegression()
regressor_cdtx.fit(cdtx_X, cdtx_y)
# Out:
# LinearRegression()

# %%
regressor_dp = LinearRegression()
regressor_dp.fit(dp_X, dp_y)
# Out:
# LinearRegression()

# %%
regressor_remit= LinearRegression()
regressor_remit.fit(remit_X, remit_y)
# Out:
# LinearRegression()

# %%
cdtx_test_new = cdtx_test.iloc[:,1:].values

# %%
dp_test_new = dp_test.iloc[:,1:].values

# %%
remit_test_new = remit_test.iloc[:,1:].values

# %%
cdtx_test_X = cdtx_ct.transform(cdtx_test_new)

# %%
dp_test_X = dp_ct.transform(dp_test_new)

# %%
remit_test_X = remit_ct.transform(remit_test_new)

# %%
cdtx_test_X
# Out:
# <2128x366 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17017 stored elements in Compressed Sparse Row format>

# %%
dp_test_X
# Out:
# <13551x1874 sparse matrix of type '<class 'numpy.float64'>'
# 	with 200648 stored elements in Compressed Sparse Row format>

# %%
remit_test_X
# Out:
# <537x280 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3759 stored elements in Compressed Sparse Row format>

# %%
cdtx_y_pred = regressor_cdtx.predict(cdtx_test_X)
cdtx_y_pred
# Out:
# array([ 0.00016931,  0.000146  , -0.00244603, ...,  0.00361298,
#         0.13536221,  0.0312051 ])

# %%
dp_y_pred = regressor_dp.predict(dp_test_X)
dp_y_pred
# Out:
# 2125     364977     0.003613
# 2126     364983     0.135362
# 2127     364983     0.031205
#
# [2128 rows x 2 columns]

# %%
dp_ans = pd.DataFrame(dp_test['alert_key'])
dp_ans['probability'] = dp_y_pred
dp_ans
# Out:
#        alert_key  probability
# 0         352249     0.023884
# 1         352249     0.025568
# 2         352249     0.023893
# 3         352249     0.004917
# 4         352249     0.032657
# ...          ...          ...
# 13546     364993     0.005991
# 13547     364993     0.006598
# 13548     364993     0.033767
# 13549     364993     0.006681
# 13550     364993     0.006610
#
# [13551 rows x 2 columns]

# %%
remit_ans = pd.DataFrame(remit_test['alert_key'])
remit_ans['probability'] = remit_y_pred
remit_ans
# Out:
#      alert_key  probability
# 0       352253     0.043208
# 1       354177     0.043205
# 2       354569     0.043205
# 3       355347     0.043208
# 4       356569     0.043229
# ..         ...          ...
# 532     364673     0.049652
# 533     364753     0.010351
# 534     364775     0.010205
# 535     364788     0.047523
# 536     364993     0.044805
#
# [537 rows x 2 columns]

# %%
ans = pd.concat([cdtx_ans,dp_ans,remit_ans])

# %%
ans
# Out:
#      alert_key  probability
# 0       352291     0.000169
# 1       352291     0.000146
# 2       352298    -0.002446
# 3       352298    -0.002446
# 4       353041    -0.002446
# ..         ...          ...
# 532     364673     0.049652
# 533     364753     0.010351
# 534     364775     0.010205
# 535     364788     0.047523
# 536     364993     0.044805
#
# [16216 rows x 2 columns]

# %%
ans['probability'] = ans['probability'].abs()

# %%
ans_mean = ans.groupby(['alert_key']).mean()

# %%
ans_mean
# Out:
#            probability
# alert_key
# 352249        0.014582
# 352253        0.040733
# 352254        0.004613
# 352280        0.011564
# 352282        0.012430
# ...                ...
# 365001        0.044768
# 365004        0.007862
# 365008        0.009119
# 365009        0.029819
# 365073        0.015341
#
# [1528 rows x 1 columns]

# %%
submit = pd.read_csv('/home/bill/moneylaundring/dataset/submit.csv')

# %%
submit['probability']=0

# %%
submit
# Out:
#       alert_key  probability
# 0        357307            0
# 1        376329            0
# 2        373644            0
# 3        357668            0
# 4        354443            0
# ...         ...          ...
# 3845     364485            0
# 3846     363155            0
# 3847     368710            0
# 3848     358067            0
# 3849     372119            0
#
# [3850 rows x 2 columns]

# %%
submit_new = pd.merge(submit, ans_mean, on=['alert_key'],how='left')

# %%
submit_new['probability_y'].fillna(0,inplace=True)

# %%
submit_final = submit_new.rename(columns={'probability_y':'probability'})

# %%
submit_final = submit_final[['alert_key','probability']]

# %%
submit_final = submit_final.sort_values(by ='probability', ascending=False)

# %%
submit_final
# Out:
#       alert_key  probability
# 1467     364467     0.328434
# 341      360833     0.317928
# 77       355751     0.296979
# 1410     364223     0.290135
# 374      356612     0.258303
# ...         ...          ...
# 1595     377601     0.000000
# 1596     369441     0.000000
# 1599     374756     0.000000
# 1600     367411     0.000000
# 3849     372119     0.000000
#
# [3850 rows x 2 columns]

# %%
submit_final.to_csv('/home/bill/moneylaundring/contest/submissions/linear_regression_submit.csv')
